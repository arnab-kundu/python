# %% [markdown]
# # Pandas

# %% [markdown]
# ### Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Read `.csv` file
# df stands for `dataframe`

# %%
df = pd.read_csv('./big.csv')

# %% [markdown]
# ### Some methods and attributes of dataframe

# %%
df
# Out:
#                         date routeCode serviceVehicle    tripId  vehicleId  \
# 0        2012-10-01 00:00:00         E            E-2  27098313        101
# 1        2012-10-01 00:00:00         E            E-2  27098313        101
# 2        2012-10-01 00:00:00         E            E-2  27098313        101
# 3        2012-10-01 00:00:00         E            E-2  27098313        101
# 4        2012-10-01 00:00:00         E            E-2  27098313        101
# ...                      ...       ...            ...       ...        ...
# 1169053  2012-10-07 00:00:00        12           12-6  27166600        899
# 1169054  2012-10-07 00:00:00        12           12-6  27166601        899
# 1169055  2012-10-07 00:00:00        12           12-6  27166601        899
# 1169056  2012-10-07 00:00:00        12           12-6  27166601        899
# 1169057  2012-10-07 00:00:00        12           12-6  27166601        899
#
# ...

# %%
df.shape
# Out:
# (1169058, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1169058 entries, 0 to 1169057
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   date                     1169058 non-null  object
#  1   routeCode                1168882 non-null  object
#  2   serviceVehicle           1169041 non-null  object
#  3   tripId                   1169058 non-null  int64
#  4   vehicleId                1169058 non-null  int64
#  5   patternId                1169058 non-null  int64
#  6   tripDirection            1169058 non-null  object
#  7   tripLength               1169058 non-null  int64
#  8   stopSequenceNr           1169058 non-null  int64
#  9   stopCode                 1169058 non-null  object
#  10  stopLength               1169058 non-null  int64
#  11  stopTimeSchedule         1154270 non-null  object
#  12  stopTimeReal             1169058 non-null  object
# ...

# %% [markdown]
# ### Get the top 5 value of datafream using `df.head()`

# %%
df.head()
# Out:
#                   date routeCode serviceVehicle    tripId  vehicleId  \
# 0  2012-10-01 00:00:00         E            E-2  27098313        101
# 1  2012-10-01 00:00:00         E            E-2  27098313        101
# 2  2012-10-01 00:00:00         E            E-2  27098313        101
# 3  2012-10-01 00:00:00         E            E-2  27098313        101
# 4  2012-10-01 00:00:00         E            E-2  27098313        101
#
#    patternId tripDirection  tripLength  stopSequenceNr stopCode  ...  \
# 0          4             A       13331               1   RIVE03  ...
# 1          4             A       13331               2   VOLL02  ...
# 2          4             A       13331               3   PLGE01  ...
# 3          4             A       13331               4   CRIG00  ...
# 4          4             A       13331               5   MGRE00  ...
#
#    passengerCountDoor3Down passengerCountDoor4Up passengerCountDoor4Down  \
# ...

# %% [markdown]
# ### Get the last 5 value of datafream using `df.tail()`

# %%
df.tail()
# Out:
#                         date routeCode serviceVehicle    tripId  vehicleId  \
# 1169053  2012-10-07 00:00:00        12           12-6  27166600        899
# 1169054  2012-10-07 00:00:00        12           12-6  27166601        899
# 1169055  2012-10-07 00:00:00        12           12-6  27166601        899
# 1169056  2012-10-07 00:00:00        12           12-6  27166601        899
# 1169057  2012-10-07 00:00:00        12           12-6  27166601        899
#
#          patternId tripDirection  tripLength  stopSequenceNr stopCode  ...  \
# 1169053         24             R       10403              29   PALE06  ...
# 1169054         16             A        1178               1   PALE06  ...
# 1169055         16             A        1178               2   PONT01  ...
# 1169056         16             A        1178               3   TRBL00  ...
# 1169057         16             A        1178               4   BHET00  ...
#
#          passengerCountDoor3Down passengerCountDoor4Up  \
# ...

# %% [markdown]
# ### We can spcify value in `head()` & `tail()`
# Like this get those spcified values only

# %%
df.head(3)

# %%
df.tail(2)

# %% [markdown]
# ### Modify default values of pd
# 1. By default pd displays only 20 columns.
# 2. To see all the columns found in `df.shape` commend,
# 3. use this below `set_option()`

# %%
pd.set_option('display.max_columns',33)
